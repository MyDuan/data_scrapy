# %%
import sqlite3
import re
import matplotlib.pyplot as plt

conn = sqlite3.connect('./data.db')
c = conn.cursor()

c.execute('select * from movies')

all_movies = c.fetchall()

# %%
year_list = []
for item in all_movies:
    year = int(re.findall('\d+', item[4])[0])
    year_list.append(year)

# %%
plt.hist(year_list, bins=40, facecolor="blue", edgecolor="black", alpha=0.7)
plt.xlabel("year")
plt.ylabel("count")
plt.title("Movie year")
plt.show()

# %%
country_movie_list = []
r1 = '[a-zA-Z0-9’!"#$%&\'()*+,-./:;<=>?@，。?★、…【】《》？“”‘’！[\\]^_`{|}~]+'
for item in all_movies:
    countries = item[5].split(' ')
    for item_ in countries:
        contry_ = re.sub(r1, '', item_)
        if contry_:
            country_movie_list.append(contry_)
plt.hist(country_movie_list, bins=50, facecolor="blue", edgecolor="black", alpha=0.7)
plt.xlabel("country")
plt.ylabel("count")
plt.title("Movie country")
plt.show()

import pandas as pd
pd.value_counts(country_movie_list)
# Out:
# 美国        141
# 英国         34
# 日本         33
# 中国香港       26
# 法国         20
# 德国         20
# 中国大陆       19
# 韩国         11
# 意大利        10
# 澳大利亚        7
# 加拿大         7
# 中国台湾        6
# 西班牙         5
# 瑞士          4
# 印度          4
# 新西兰         3
# 伊朗          2
# 南非          2
# 巴西          2
# 瑞典          2
# 黎巴嫩         1
# 爱尔兰         1
# 捷克          1
# 阿联酋         1
# 波兰          1
# 西德          1
# 奥地利         1
# 泰国          1
# 中国大陆重映      1
# 丹麦          1
# 冰岛          1
# 荷兰          1
# 希腊          1
# 阿根廷         1
# dtype: int64

# %%
key_words_list = []
r1 = '[a-zA-Z0-9’!"#$%&\'()*+,-./:;<=>?@，。?★、…【】《》？“”‘’！[\\]^_`{|}~]+'
for item in all_movies:
    key_words = item[6].split(' ')
    for item_ in key_words:
        key_word_ = re.sub(r1, '', item_)
        if key_word_:
            key_words_list.append(key_word_)
plt.hist(key_words_list, bins=50, facecolor="blue", edgecolor="black", alpha=0.7)
plt.xlabel("key_words")
plt.ylabel("count")
plt.title("Movie key words")
plt.show()

import pandas as pd
pd.value_counts(key_words_list)
# Out:
# 剧情      186
# 爱情       56
# 喜剧       49
# 冒险       46
# 犯罪       45
# 奇幻       37
# 惊悚       36
# 动画       33
# 动作       33
# 悬疑       31
# 科幻       26
# 家庭       21
# 战争       18
# 传记       13
# 历史       12
# 古装        8
# 同性        7
# 音乐        6
# 儿童        5
# 歌舞        5
# 西部        4
# 武侠        4
# 纪录片       3
# 灾难        2
# 恐怖        2
# 中国大陆      2
# 运动        1
# 情色        1
# dtype: int64

# %%
directors_list = []
r1 = '[a-zA-Z0-9’!"#$%&\'()*+,-./:;<=>?@，。?★、…【】《》？“”‘’！[\\]^_`{|}~]+'
for item in all_movies:
    directors = item[3].split(' ')
    for item_ in directors:
        director_ = re.sub(r1, '', item_)
        if director_:
            directors_list.append(director_)
plt.hist(directors_list, bins=169, facecolor="blue", edgecolor="black", alpha=0.7)
plt.xlabel("directors")
plt.ylabel("count")
plt.title("Movie directors")
plt.show()

import pandas as pd
pd.value_counts(directors_list)
# Out:
# 宫崎骏          7
# 史蒂文·斯皮尔伯格    7
# 克里斯托弗·诺兰     7
# 王家卫          5
# 大卫·芬奇        4
#             ..
# 安德鲁·斯坦顿      1
# 乔纳森·戴米       1
# 马克·赫尔曼       1
# 周申           1
# 克里斯托夫·巴拉蒂    1
# Length: 169, dtype: int64

# %%
c.execute('select serial_number, movie_name, evaluate_num from movies order by evaluate_num  desc')

movies = c.fetchall()
for item in movies:
    print("serial_number:" + str(item[0]) + '| ' + "movie_name:" + item[1] + '| ' + "evaluate_num:" + str(item[2]))
# Out:
# serial_number:228| movie_name:城市之光| evaluate_num:66447.0
# serial_number:248| movie_name:黄金三镖客| evaluate_num:72279.0
# serial_number:229| movie_name:东京物语| evaluate_num:74173.0
# serial_number:243| movie_name:我爱你| evaluate_num:86289.0
# serial_number:182| movie_name:天书奇谭| evaluate_num:95674.0
# serial_number:181| movie_name:忠犬八公物语| evaluate_num:99426.0
# serial_number:222| movie_name:追随| evaluate_num:109967.0
# serial_number:144| movie_name:七武士| evaluate_num:110559.0
# serial_number:178| movie_name:海洋| evaluate_num:117456.0
# serial_number:209| movie_name:地球上的星星| evaluate_num:123109.0
# serial_number:156| movie_name:完美的世界| evaluate_num:126594.0
# serial_number:179| movie_name:雨中曲| evaluate_num:126871.0
# serial_number:194| movie_name:惊魂记| evaluate_num:129428.0
# serial_number:166| movie_name:哪吒闹海| evaluate_num:134071.0
# serial_number:246| movie_name:千钧一发| evaluate_num:134162.0
# serial_number:134| movie_name:无人知晓| evaluate_num:138067.0
# serial_number:238| movie_name:末路狂花| evaluate_num:139934.0
# serial_number:216| movie_name:步履不停| evaluate_num:143033.0
# serial_number:174| movie_name:虎口脱险| evaluate_num:143154.0
# serial_number:232| movie_name:梦之安魂曲| evaluate_num:146440.0
# serial_number:224| movie_name:绿里奇迹| evaluate_num:149971.0
# serial_number:175| movie_name:未麻的部屋| evaluate_num:151189.0
# serial_number:113| movie_name:海蒂和爷爷| evaluate_num:152147.0
# serial_number:201| movie_name:牯岭街少年杀人事件| evaluate_num:152194.0
# serial_number:226| movie_name:2001太空漫游| evaluate_num:152812.0
# serial_number:92| movie_name:摩登时代| evaluate_num:153032.0
# serial_number:223| movie_name:新世界| evaluate_num:156098.0
# serial_number:163| movie_name:我是山姆| evaluate_num:161627.0
# serial_number:165| movie_name:卢旺达饭店| evaluate_num:163962.0
# serial_number:249| movie_name:非常嫌疑犯| evaluate_num:165874.0
# serial_number:192| movie_name:魂断蓝桥| evaluate_num:167066.0
# serial_number:221| movie_name:一次别离| evaluate_num:170405.0
# serial_number:213| movie_name:爱在午夜降临前| evaluate_num:170657.0
# serial_number:235| movie_name:黑鹰坠落| evaluate_num:172609.0
# serial_number:172| movie_name:二十二| evaluate_num:173242.0
# serial_number:200| movie_name:可可西里| evaluate_num:173556.0
# serial_number:233| movie_name:聚焦| evaluate_num:175203.0
# serial_number:205| movie_name:浪潮| evaluate_num:175561.0
# serial_number:197| movie_name:罗生门| evaluate_num:178303.0
# serial_number:245| movie_name:勇闯夺命岛| evaluate_num:184511.0
# serial_number:183| movie_name:燃情岁月| evaluate_num:187373.0
# serial_number:155| movie_name:教父3| evaluate_num:195851.0
# serial_number:236| movie_name:遗愿清单| evaluate_num:195971.0
# serial_number:60| movie_name:大闹天宫| evaluate_num:196453.0
# serial_number:143| movie_name:喜宴| evaluate_num:198542.0
# serial_number:180| movie_name:一个叫欧维的男人决定去死| evaluate_num:200378.0
# serial_number:99| movie_name:狩猎| evaluate_num:200405.0
# serial_number:225| movie_name:血钻| evaluate_num:200551.0
# serial_number:122| movie_name:小森林 冬春篇| evaluate_num:201235.0
# serial_number:212| movie_name:终结者2：审判日| evaluate_num:202286.0
# serial_number:132| movie_name:上帝之城| evaluate_num:202889.0
# serial_number:169| movie_name:你看起来好像很好吃| evaluate_num:205610.0
# serial_number:29| movie_name:控方证人| evaluate_num:206565.0
# serial_number:107| movie_name:一一| evaluate_num:213056.0
# serial_number:234| movie_name:E.T. 外星人| evaluate_num:214524.0
# serial_number:114| movie_name:红辣椒| evaluate_num:216379.0
# serial_number:190| movie_name:海街日记| evaluate_num:219494.0
# serial_number:230| movie_name:撞车| evaluate_num:221504.0
# serial_number:202| movie_name:谍影重重2| evaluate_num:222148.0
# serial_number:68| movie_name:小鞋子| evaluate_num:223563.0
# serial_number:207| movie_name:战争之王| evaluate_num:228190.0
# serial_number:157| movie_name:荒蛮故事| evaluate_num:228762.0
# serial_number:188| movie_name:黑客帝国3：矩阵革命| evaluate_num:231192.0
# serial_number:154| movie_name:纵横四海| evaluate_num:231721.0
# serial_number:104| movie_name:小森林 夏秋篇| evaluate_num:231943.0
# serial_number:186| movie_name:房间| evaluate_num:233703.0
# serial_number:239| movie_name:发条橙| evaluate_num:240834.0
# serial_number:237| movie_name:这个男人来自地球| evaluate_num:247899.0
# serial_number:125| movie_name:风之谷| evaluate_num:248942.0
# serial_number:59| movie_name:海豚湾| evaluate_num:249723.0
# serial_number:220| movie_name:再次出发之纽约遇见你| evaluate_num:249800.0
# serial_number:70| movie_name:美国往事| evaluate_num:252354.0
# serial_number:187| movie_name:穿越时空的少女| evaluate_num:254254.0
# serial_number:140| movie_name:谍影重重3| evaluate_num:259210.0
# serial_number:119| movie_name:超脱| evaluate_num:262055.0
# serial_number:111| movie_name:侧耳倾听| evaluate_num:262243.0
# serial_number:35| movie_name:十二怒汉| evaluate_num:262259.0
# serial_number:184| movie_name:人工智能| evaluate_num:262790.0
# serial_number:214| movie_name:新龙门客栈| evaluate_num:262928.0
# serial_number:204| movie_name:谍影重重| evaluate_num:264769.0
# serial_number:80| movie_name:穿条纹睡衣的男孩| evaluate_num:265283.0
# serial_number:240| movie_name:哈利·波特与阿兹卡班的囚徒| evaluate_num:269121.0
# serial_number:128| movie_name:萤火之森| evaluate_num:269177.0
# serial_number:158| movie_name:达拉斯买家俱乐部| evaluate_num:269277.0
# serial_number:161| movie_name:雨人| evaluate_num:270875.0
# serial_number:242| movie_name:变脸| evaluate_num:275874.0
# serial_number:146| movie_name:萤火虫之墓| evaluate_num:276485.0
# serial_number:218| movie_name:小萝莉的猴神大叔| evaluate_num:278792.0
# serial_number:153| movie_name:心迷宫| evaluate_num:279794.0
# serial_number:227| movie_name:彗星来的那一夜| evaluate_num:282467.0
# serial_number:142| movie_name:英雄本色| evaluate_num:283753.0
# serial_number:118| movie_name:7号房的礼物| evaluate_num:284557.0
# serial_number:136| movie_name:玩具总动员3| evaluate_num:284983.0
# serial_number:185| movie_name:魔女宅急便| evaluate_num:285635.0
# serial_number:241| movie_name:哈利·波特与密室| evaluate_num:288443.0
# serial_number:124| movie_name:爱在日落黄昏时| evaluate_num:290844.0
# serial_number:123| movie_name:菊次郎的夏天| evaluate_num:291339.0
# serial_number:101| movie_name:玛丽和马克思| evaluate_num:293372.0
# serial_number:137| movie_name:电锯惊魂| evaluate_num:294010.0
# serial_number:52| movie_name:教父2| evaluate_num:297454.0
# serial_number:62| movie_name:钢琴家| evaluate_num:298720.0
# serial_number:219| movie_name:无耻混蛋| evaluate_num:299017.0
# serial_number:168| movie_name:海边的曼彻斯特| evaluate_num:299992.0
# serial_number:198| movie_name:阿飞正传| evaluate_num:300854.0
# serial_number:231| movie_name:疯狂的麦克斯4：狂暴之路| evaluate_num:302705.0
# serial_number:210| movie_name:青蛇| evaluate_num:308793.0
# serial_number:193| movie_name:猜火车| evaluate_num:309258.0
# serial_number:148| movie_name:时空恋旅人| evaluate_num:309401.0
# serial_number:112| movie_name:甜蜜蜜| evaluate_num:311696.0
# serial_number:171| movie_name:无敌破坏王| evaluate_num:312833.0
# serial_number:130| movie_name:借东西的小人阿莉埃蒂| evaluate_num:314342.0
# serial_number:127| movie_name:幸福终点站| evaluate_num:315507.0
# serial_number:58| movie_name:饮食男女| evaluate_num:319323.0
# serial_number:115| movie_name:杀人回忆| evaluate_num:328563.0
# serial_number:177| movie_name:爆裂鼓手| evaluate_num:329454.0
# serial_number:211| movie_name:奇迹男孩| evaluate_num:331127.0
# serial_number:98| movie_name:第六感| evaluate_num:331288.0
# serial_number:46| movie_name:素媛| evaluate_num:332967.0
# serial_number:108| movie_name:爱在黎明破晓前| evaluate_num:333394.0
# serial_number:203| movie_name:朗读者| evaluate_num:336342.0
# serial_number:106| movie_name:请以你的名字呼唤我| evaluate_num:337337.0
# serial_number:195| movie_name:完美陌生人| evaluate_num:339216.0
# serial_number:90| movie_name:幽灵公主| evaluate_num:341091.0
# serial_number:162| movie_name:花样年华| evaluate_num:342454.0
# serial_number:47| movie_name:窃听风暴| evaluate_num:345902.0
# serial_number:167| movie_name:头脑特工队| evaluate_num:346423.0
# serial_number:73| movie_name:音乐之声| evaluate_num:348214.0
# serial_number:45| movie_name:辩护人| evaluate_num:349847.0
# serial_number:105| movie_name:大鱼| evaluate_num:353868.0
# serial_number:120| movie_name:恐怖直播| evaluate_num:357020.0
# serial_number:176| movie_name:模仿游戏| evaluate_num:361391.0
# serial_number:160| movie_name:被解救的姜戈| evaluate_num:364534.0
# serial_number:41| movie_name:末代皇帝| evaluate_num:366528.0
# serial_number:199| movie_name:香水| evaluate_num:367296.0
# serial_number:34| movie_name:鬼子来了| evaluate_num:368621.0
# serial_number:147| movie_name:东邪西毒| evaluate_num:368945.0
# serial_number:135| movie_name:怪兽电力公司| evaluate_num:371031.0
# serial_number:49| movie_name:两杆大烟枪| evaluate_num:374566.0
# serial_number:81| movie_name:春光乍泄| evaluate_num:375049.0
# serial_number:71| movie_name:拯救大兵瑞恩| evaluate_num:377227.0
# serial_number:152| movie_name:记忆碎片| evaluate_num:378519.0
# serial_number:50| movie_name:飞越疯人院| evaluate_num:378890.0
# serial_number:56| movie_name:何以为家| evaluate_num:380091.0
# serial_number:109| movie_name:阳光姐妹淘| evaluate_num:384686.0
# serial_number:96| movie_name:阳光灿烂的日子| evaluate_num:385280.0
# serial_number:173| movie_name:冰川时代| evaluate_num:385817.0
# serial_number:110| movie_name:射雕英雄传之东成西就| evaluate_num:390933.0
# serial_number:170| movie_name:恋恋笔记本| evaluate_num:391805.0
# serial_number:82| movie_name:勇敢的心| evaluate_num:392852.0
# serial_number:138| movie_name:岁月神偷| evaluate_num:399288.0
# serial_number:27| movie_name:乱世佳人| evaluate_num:401248.0
# serial_number:89| movie_name:入殓师| evaluate_num:405903.0
# serial_number:117| movie_name:倩女幽魂| evaluate_num:408497.0
# serial_number:85| movie_name:心灵捕手| evaluate_num:410182.0
# serial_number:51| movie_name:指环王2：双塔奇兵| evaluate_num:411074.0
# serial_number:121| movie_name:哈利·波特与死亡圣器(下)| evaluate_num:416691.0
# serial_number:72| movie_name:猫鼠游戏| evaluate_num:417131.0
# serial_number:250| movie_name:秒速5厘米| evaluate_num:419638.0
# serial_number:48| movie_name:死亡诗社| evaluate_num:421294.0
# serial_number:37| movie_name:天堂电影院| evaluate_num:421914.0
# serial_number:126| movie_name:蝙蝠侠：黑暗骑士崛起| evaluate_num:423404.0
# serial_number:149| movie_name:真爱至上| evaluate_num:436014.0
# serial_number:145| movie_name:傲慢与偏见| evaluate_num:438181.0
# serial_number:32| movie_name:指环王3：王者无敌| evaluate_num:439982.0
# serial_number:244| movie_name:国王的演讲| evaluate_num:440990.0
# serial_number:66| movie_name:黑客帝国| evaluate_num:444642.0
# serial_number:116| movie_name:驯龙高手| evaluate_num:447101.0
# serial_number:57| movie_name:美丽心灵| evaluate_num:450969.0
# serial_number:53| movie_name:狮子王| evaluate_num:451070.0
# serial_number:76| movie_name:被嫌弃的松子的一生| evaluate_num:453983.0
# serial_number:28| movie_name:活着| evaluate_num:454114.0
# serial_number:94| movie_name:断背山| evaluate_num:455627.0
# serial_number:206| movie_name:疯狂的石头| evaluate_num:460761.0
# serial_number:54| movie_name:指环王1：魔戒再现| evaluate_num:461530.0
# serial_number:93| movie_name:致命ID| evaluate_num:462584.0
# serial_number:191| movie_name:恐怖游轮| evaluate_num:467248.0
# serial_number:103| movie_name:告白| evaluate_num:473924.0
# serial_number:97| movie_name:重庆森林| evaluate_num:479390.0
# serial_number:196| movie_name:功夫| evaluate_num:481627.0
# serial_number:63| movie_name:哈利·波特与魔法石| evaluate_num:481696.0
# serial_number:139| movie_name:血战钢锯岭| evaluate_num:481910.0
# serial_number:44| movie_name:闻香识女人| evaluate_num:502839.0
# serial_number:150| movie_name:贫民窟的百万富翁| evaluate_num:503491.0
# serial_number:159| movie_name:三块广告牌| evaluate_num:503652.0
# serial_number:77| movie_name:低俗小说| evaluate_num:503807.0
# serial_number:78| movie_name:沉默的羔羊| evaluate_num:505820.0
# serial_number:74| movie_name:致命魔术| evaluate_num:506592.0
# serial_number:19| movie_name:熔炉| evaluate_num:507776.0
# serial_number:87| movie_name:布达佩斯大饭店| evaluate_num:511142.0
# serial_number:247| movie_name:驴得水| evaluate_num:514373.0
# serial_number:33| movie_name:天空之城| evaluate_num:515651.0
# serial_number:215| movie_name:源代码| evaluate_num:526095.0
# serial_number:100| movie_name:喜剧之王| evaluate_num:526224.0
# serial_number:141| movie_name:疯狂原始人| evaluate_num:527967.0
# serial_number:91| movie_name:加勒比海盗| evaluate_num:529120.0
# serial_number:102| movie_name:消失的爱人| evaluate_num:534555.0
# serial_number:20| movie_name:教父| evaluate_num:547724.0
# serial_number:86| movie_name:禁闭岛| evaluate_num:547985.0
# serial_number:43| movie_name:搏击俱乐部| evaluate_num:550831.0
# serial_number:61| movie_name:情书| evaluate_num:553248.0
# serial_number:151| movie_name:黑天鹅| evaluate_num:556611.0
# serial_number:79| movie_name:蝴蝶效应| evaluate_num:558359.0
# serial_number:129| movie_name:唐伯虎点秋香| evaluate_num:560343.0
# serial_number:67| movie_name:西西里的美丽传说| evaluate_num:564497.0
# serial_number:26| movie_name:蝙蝠侠：黑暗骑士| evaluate_num:575974.0
# serial_number:131| movie_name:超能陆战队| evaluate_num:578166.0
# serial_number:25| movie_name:触不可及| evaluate_num:580616.0
# serial_number:217| movie_name:釜山行| evaluate_num:580807.0
# serial_number:39| movie_name:哈尔的移动城堡| evaluate_num:580868.0
# serial_number:133| movie_name:神偷奶爸| evaluate_num:584546.0
# serial_number:42| movie_name:罗马假日| evaluate_num:587351.0
# serial_number:64| movie_name:本杰明·巴顿奇事| evaluate_num:588322.0
# serial_number:75| movie_name:七宗罪| evaluate_num:602513.0
# serial_number:8| movie_name:辛德勒的名单| evaluate_num:638138.0
# serial_number:208| movie_name:初恋这件小事| evaluate_num:644651.0
# serial_number:55| movie_name:V字仇杀队| evaluate_num:646284.0
# serial_number:65| movie_name:看不见的客人| evaluate_num:651592.0
# serial_number:83| movie_name:天使爱美丽| evaluate_num:666922.0
# serial_number:84| movie_name:剪刀手爱德华| evaluate_num:686659.0
# serial_number:38| movie_name:大话西游之月光宝盒| evaluate_num:691713.0
# serial_number:21| movie_name:无间道| evaluate_num:703204.0
# serial_number:5| movie_name:美丽人生| evaluate_num:720743.0
# serial_number:18| movie_name:龙猫| evaluate_num:754193.0
# serial_number:13| movie_name:放牛班的春天| evaluate_num:766381.0
# serial_number:164| movie_name:你的名字。| evaluate_num:776705.0
# serial_number:36| movie_name:飞屋环游记| evaluate_num:790517.0
# serial_number:88| movie_name:阿凡达| evaluate_num:802058.0
# serial_number:11| movie_name:机器人总动员| evaluate_num:806071.0
# serial_number:10| movie_name:忠犬八公的故事| evaluate_num:815685.0
# serial_number:40| movie_name:寻梦环游记| evaluate_num:832773.0
# serial_number:189| movie_name:头号玩家| evaluate_num:842274.0
# serial_number:15| movie_name:楚门的世界| evaluate_num:854108.0
# serial_number:17| movie_name:大话西游之大圣娶亲| evaluate_num:856429.0
# serial_number:30| movie_name:少年派的奇幻漂流| evaluate_num:869380.0
# serial_number:31| movie_name:摔跤吧！爸爸| evaluate_num:872437.0
# serial_number:16| movie_name:星际穿越| evaluate_num:875555.0
# serial_number:14| movie_name:海上钢琴师| evaluate_num:889655.0
# serial_number:23| movie_name:当幸福来敲门| evaluate_num:890860.0
# serial_number:69| movie_name:让子弹飞| evaluate_num:955982.0
# serial_number:22| movie_name:疯狂动物城| evaluate_num:990281.0
# serial_number:24| movie_name:怦然心动| evaluate_num:997790.0
# serial_number:12| movie_name:三傻大闹宝莱坞| evaluate_num:1100476.0
# serial_number:2| movie_name:霸王别姬| evaluate_num:1169298.0
# serial_number:6| movie_name:泰坦尼克号| evaluate_num:1172461.0
# serial_number:95| movie_name:我不是药神| evaluate_num:1209928.0
# serial_number:9| movie_name:盗梦空间| evaluate_num:1215256.0
# serial_number:3| movie_name:阿甘正传| evaluate_num:1231158.0
# serial_number:7| movie_name:千与千寻| evaluate_num:1263720.0
# serial_number:4| movie_name:这个杀手不太冷| evaluate_num:1422932.0
# serial_number:1| movie_name:肖申克的救赎| evaluate_num:1583111.0
