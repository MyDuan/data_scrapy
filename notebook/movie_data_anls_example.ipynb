# %%
import sqlite3
import re
import matplotlib.pyplot as plt

conn = sqlite3.connect('./data_example.db')
c = conn.cursor()

c.execute('select * from movies')

all_movies = c.fetchall()

# %%
year_list = []
for item in all_movies:
    year = int(re.findall('\d+', item[4])[0])
    year_list.append(year)

# %%
plt.hist(year_list, bins=40, facecolor="blue", edgecolor="black", alpha=0.7)
plt.xlabel("year")
plt.ylabel("count")
plt.title("Movie year")
plt.show()

# %%
country_movie_list = []
r1 = '[a-zA-Z0-9’!"#$%&\'()*+,-./:;<=>?@，。?★、…【】《》？“”‘’！[\\]^_`{|}~]+'
for item in all_movies:
    countries = item[5].split(' ')
    for item_ in countries:
        contry_ = re.sub(r1, '', item_)
        if contry_:
            country_movie_list.append(contry_)
plt.hist(country_movie_list, bins=50, facecolor="blue", edgecolor="black", alpha=0.7)
plt.xlabel("country")
plt.ylabel("count")
plt.title("Movie country")
plt.show()

import pandas as pd
pd.value_counts(country_movie_list)
# Out:
# 美国        141
# 英国         34
# 日本         33
# 中国香港       26
# 法国         20
# 德国         20
# 中国大陆       19
# 韩国         11
# 意大利        10
# 加拿大         7
# 澳大利亚        7
# 中国台湾        6
# 西班牙         5
# 印度          4
# 瑞士          4
# 新西兰         3
# 瑞典          2
# 伊朗          2
# 巴西          2
# 南非          2
# 阿根廷         1
# 奥地利         1
# 丹麦          1
# 西德          1
# 黎巴嫩         1
# 泰国          1
# 爱尔兰         1
# 捷克          1
# 冰岛          1
# 荷兰          1
# 中国大陆重映      1
# 阿联酋         1
# 希腊          1
# 波兰          1
# dtype: int64

# %%
key_words_list = []
r1 = '[a-zA-Z0-9’!"#$%&\'()*+,-./:;<=>?@，。?★、…【】《》？“”‘’！[\\]^_`{|}~]+'
for item in all_movies:
    key_words = item[6].split(' ')
    for item_ in key_words:
        key_word_ = re.sub(r1, '', item_)
        if key_word_:
            key_words_list.append(key_word_)
plt.hist(key_words_list, bins=50, facecolor="blue", edgecolor="black", alpha=0.7)
plt.xlabel("key_words")
plt.ylabel("count")
plt.title("Movie key words")
plt.show()

import pandas as pd
pd.value_counts(key_words_list)
# Out:
# 剧情      186
# 爱情       56
# 喜剧       49
# 冒险       46
# 犯罪       45
# 奇幻       37
# 惊悚       36
# 动画       33
# 动作       33
# 悬疑       31
# 科幻       26
# 家庭       21
# 战争       18
# 传记       13
# 历史       12
# 古装        8
# 同性        7
# 音乐        6
# 歌舞        5
# 儿童        5
# 武侠        4
# 西部        4
# 纪录片       3
# 恐怖        2
# 灾难        2
# 中国大陆      2
# 情色        1
# 运动        1
# dtype: int64

# %%
directors_list = []
r1 = '[a-zA-Z0-9’!"#$%&\'()*+,-./:;<=>?@，。?★、…【】《》？“”‘’！[\\]^_`{|}~]+'
for item in all_movies:
    directors = item[3].split(' ')
    for item_ in directors:
        director_ = re.sub(r1, '', item_)
        if director_:
            directors_list.append(director_)
plt.hist(directors_list, bins=169, facecolor="blue", edgecolor="black", alpha=0.7)
plt.xlabel("directors")
plt.ylabel("count")
plt.title("Movie directors")
plt.show()

import pandas as pd
pd.value_counts(directors_list)
# Out:
# 史蒂文·斯皮尔伯格    7
# 克里斯托弗·诺兰     7
# 宫崎骏          7
# 王家卫          5
# 大卫·芬奇        4
#             ..
# 詹姆斯·温        1
# 罗伯特·怀斯       1
# 罗伯特·泽米吉斯     1
# 托马斯·麦卡锡      1
# 皮艾尔·柯芬       1
# Length: 169, dtype: int64

# %%
c.execute('select serial_number, movie_name, evaluate_num from movies order by evaluate_num  desc')

movies = c.fetchall()
for item in movies:
    print("serial_number:" + str(item[0]) + '| ' + "movie_name:" + item[1] + '| ' + "evaluate_num:" + str(item[2]))
# Out:
# serial_number:1| movie_name:肖申克的救赎| evaluate_num:1615239.0
# serial_number:4| movie_name:这个杀手不太冷| evaluate_num:1446053.0
# serial_number:7| movie_name:千与千寻| evaluate_num:1284765.0
# serial_number:3| movie_name:阿甘正传| evaluate_num:1253596.0
# serial_number:9| movie_name:盗梦空间| evaluate_num:1233173.0
# serial_number:88| movie_name:我不是药神| evaluate_num:1229847.0
# serial_number:6| movie_name:泰坦尼克号| evaluate_num:1194023.0
# serial_number:2| movie_name:霸王别姬| evaluate_num:1193071.0
# serial_number:12| movie_name:三傻大闹宝莱坞| evaluate_num:1117337.0
# serial_number:24| movie_name:怦然心动| evaluate_num:1015329.0
# serial_number:22| movie_name:疯狂动物城| evaluate_num:1010064.0
# serial_number:69| movie_name:让子弹飞| evaluate_num:968918.0
# serial_number:23| movie_name:当幸福来敲门| evaluate_num:904642.0
# serial_number:15| movie_name:海上钢琴师| evaluate_num:901494.0
# serial_number:16| movie_name:星际穿越| evaluate_num:889565.0
# serial_number:31| movie_name:摔跤吧！爸爸| evaluate_num:888763.0
# ...
